# %% [markdown]
# # MobileNetV2 Pruning & Quantization (No Library)

# %%
import sys
sys.path.append('.')

import torch
import torch.nn as nn
from collections import OrderedDict
from models.mobilenetv2 import MobileNetV2

# ==================== Configuration ====================
CKPT_PATH = './checkpoints/mobilenetv2_ckpt_best.pth'
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# ==================== Load Model ====================
model = MobileNetV2()
ckpt = torch.load(CKPT_PATH, map_location='cpu')

# Handle DDP state_dict
state_dict = ckpt['net']
if list(state_dict.keys())[0].startswith('module.'):
    state_dict = OrderedDict([(k.replace('module.', ''), v) for k, v in state_dict.items()])
model.load_state_dict(state_dict)
model = model.to(DEVICE)
model.eval()

# ==================== Model Info ====================
print('=' * 60)
print('MobileNetV2 for CIFAR-10 - Model Information')
print('=' * 60)
print(f"Checkpoint: {CKPT_PATH}")
print(f"Best Accuracy: {ckpt.get('acc', 'N/A'):.2f}%" if 'acc' in ckpt else f"Accuracy: N/A")
print(f"Trained Epochs: {ckpt.get('epoch', 'N/A')}")
print(f"Device: {DEVICE}")
print()

# Total parameters
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total Parameters: {total_params:,}")
print(f"Trainable Parameters: {trainable_params:,}")
print(f"Model Size: {total_params * 4 / 1024 / 1024:.2f} MB (FP32)")
print()

# Layer-wise breakdown
print('Layer-wise Parameter Count:')
print('-' * 60)
conv_layers = []
depthwise_layers = []
for name, module in model.named_modules():
    if isinstance(module, nn.Conv2d):
        params = sum(p.numel() for p in module.parameters())
        is_depthwise = module.groups == module.in_channels and module.groups > 1
        layer_type = 'DWConv' if is_depthwise else 'Conv2d'
        if is_depthwise:
            depthwise_layers.append((name, module, params))
        else:
            conv_layers.append((name, module, params))
        print(f"{name:40s} | {layer_type:6s} | in={module.in_channels:4d}, out={module.out_channels:4d}, k={module.kernel_size[0]}, g={module.groups:3d} | {params:,} params")
    elif isinstance(module, nn.Linear):
        params = sum(p.numel() for p in module.parameters())
        print(f"{name:40s} | Linear | in={module.in_features:4d}, out={module.out_features:4d}              | {params:,} params")

print()
print('=' * 60)
print(f"Total Conv2d Layers (non-depthwise): {len(conv_layers)}")
print(f"Total Depthwise Conv Layers: {len(depthwise_layers)}")
print(f"Total Conv2d Parameters: {sum(p for _, _, p in conv_layers):,}")
print(f"Total Depthwise Parameters: {sum(p for _, _, p in depthwise_layers):,}")
print('=' * 60)
# Out:
# ============================================================
# MobileNetV2 for CIFAR-10 - Model Information
# ============================================================
# Checkpoint: ./checkpoints/mobilenetv2_ckpt_best.pth
# Best Accuracy: 93.85%
# Trained Epochs: 99
# Device: cuda
#
# Total Parameters: 2,296,922
# Trainable Parameters: 2,296,922
# Model Size: 8.76 MB (FP32)
#
# Layer-wise Parameter Count:
# ------------------------------------------------------------
# conv1                                    | Conv2d | in=   3, out=  32, k=3, g=  1 | 864 params
# layers.0.conv1                           | Conv2d | in=  32, out=  32, k=1, g=  1 | 1,024 params
# layers.0.conv2                           | DWConv | in=  32, out=  32, k=3, g= 32 | 288 params
# layers.0.conv3                           | Conv2d | in=  32, out=  16, k=1, g=  1 | 512 params
# layers.0.shortcut.0                      | Conv2d | in=  32, out=  16, k=1, g=  1 | 512 params
# layers.1.conv1                           | Conv2d | in=  16, out=  96, k=1, g=  1 | 1,536 params
# layers.1.conv2                           | DWConv | in=  96, out=  96, k=3, g= 96 | 864 params
# layers.1.conv3                           | Conv2d | in=  96, out=  24, k=1, g=  1 | 2,304 params
# layers.1.shortcut.0                      | Conv2d | in=  16, out=  24, k=1, g=  1 | 384 params
# layers.2.conv1                           | Conv2d | in=  24, out= 144, k=1, g=  1 | 3,456 params
# layers.2.conv2                           | DWConv | in= 144, out= 144, k=3, g=144 | 1,296 params
# layers.2.conv3                           | Conv2d | in= 144, out=  24, k=1, g=  1 | 3,456 params
# layers.3.conv1                           | Conv2d | in=  24, out= 144, k=1, g=  1 | 3,456 params
# layers.3.conv2                           | DWConv | in= 144, out= 144, k=3, g=144 | 1,296 params
# layers.3.conv3                           | Conv2d | in= 144, out=  32, k=1, g=  1 | 4,608 params
# layers.4.conv1                           | Conv2d | in=  32, out= 192, k=1, g=  1 | 6,144 params
# layers.4.conv2                           | DWConv | in= 192, out= 192, k=3, g=192 | 1,728 params
# layers.4.conv3                           | Conv2d | in= 192, out=  32, k=1, g=  1 | 6,144 params
# layers.5.conv1                           | Conv2d | in=  32, out= 192, k=1, g=  1 | 6,144 params
# layers.5.conv2                           | DWConv | in= 192, out= 192, k=3, g=192 | 1,728 params
# layers.5.conv3                           | Conv2d | in= 192, out=  32, k=1, g=  1 | 6,144 params
# layers.6.conv1                           | Conv2d | in=  32, out= 192, k=1, g=  1 | 6,144 params
# layers.6.conv2                           | DWConv | in= 192, out= 192, k=3, g=192 | 1,728 params
# layers.6.conv3                           | Conv2d | in= 192, out=  64, k=1, g=  1 | 12,288 params
# layers.7.conv1                           | Conv2d | in=  64, out= 384, k=1, g=  1 | 24,576 params
# layers.7.conv2                           | DWConv | in= 384, out= 384, k=3, g=384 | 3,456 params
# layers.7.conv3                           | Conv2d | in= 384, out=  64, k=1, g=  1 | 24,576 params
# layers.8.conv1                           | Conv2d | in=  64, out= 384, k=1, g=  1 | 24,576 params
# layers.8.conv2                           | DWConv | in= 384, out= 384, k=3, g=384 | 3,456 params
# layers.8.conv3                           | Conv2d | in= 384, out=  64, k=1, g=  1 | 24,576 params
# layers.9.conv1                           | Conv2d | in=  64, out= 384, k=1, g=  1 | 24,576 params
# layers.9.conv2                           | DWConv | in= 384, out= 384, k=3, g=384 | 3,456 params
# layers.9.conv3                           | Conv2d | in= 384, out=  64, k=1, g=  1 | 24,576 params
# layers.10.conv1                          | Conv2d | in=  64, out= 384, k=1, g=  1 | 24,576 params
# layers.10.conv2                          | DWConv | in= 384, out= 384, k=3, g=384 | 3,456 params
# layers.10.conv3                          | Conv2d | in= 384, out=  96, k=1, g=  1 | 36,864 params
# layers.10.shortcut.0                     | Conv2d | in=  64, out=  96, k=1, g=  1 | 6,144 params
# layers.11.conv1                          | Conv2d | in=  96, out= 576, k=1, g=  1 | 55,296 params
# layers.11.conv2                          | DWConv | in= 576, out= 576, k=3, g=576 | 5,184 params
# layers.11.conv3                          | Conv2d | in= 576, out=  96, k=1, g=  1 | 55,296 params
# layers.12.conv1                          | Conv2d | in=  96, out= 576, k=1, g=  1 | 55,296 params
# layers.12.conv2                          | DWConv | in= 576, out= 576, k=3, g=576 | 5,184 params
# layers.12.conv3                          | Conv2d | in= 576, out=  96, k=1, g=  1 | 55,296 params
# layers.13.conv1                          | Conv2d | in=  96, out= 576, k=1, g=  1 | 55,296 params
# layers.13.conv2                          | DWConv | in= 576, out= 576, k=3, g=576 | 5,184 params
# layers.13.conv3                          | Conv2d | in= 576, out= 160, k=1, g=  1 | 92,160 params
# layers.14.conv1                          | Conv2d | in= 160, out= 960, k=1, g=  1 | 153,600 params
# layers.14.conv2                          | DWConv | in= 960, out= 960, k=3, g=960 | 8,640 params
# layers.14.conv3                          | Conv2d | in= 960, out= 160, k=1, g=  1 | 153,600 params
# layers.15.conv1                          | Conv2d | in= 160, out= 960, k=1, g=  1 | 153,600 params
# layers.15.conv2                          | DWConv | in= 960, out= 960, k=3, g=960 | 8,640 params
# layers.15.conv3                          | Conv2d | in= 960, out= 160, k=1, g=  1 | 153,600 params
# layers.16.conv1                          | Conv2d | in= 160, out= 960, k=1, g=  1 | 153,600 params
# layers.16.conv2                          | DWConv | in= 960, out= 960, k=3, g=960 | 8,640 params
# layers.16.conv3                          | Conv2d | in= 960, out= 320, k=1, g=  1 | 307,200 params
# layers.16.shortcut.0                     | Conv2d | in= 160, out= 320, k=1, g=  1 | 51,200 params
# conv2                                    | Conv2d | in= 320, out=1280, k=1, g=  1 | 409,600 params
# linear                                   | Linear | in=1280, out=  10              | 12,810 params
#
# ============================================================
# Total Conv2d Layers (non-depthwise): 40
# Total Depthwise Conv Layers: 17
# Total Conv2d Parameters: 2,184,800
# Total Depthwise Parameters: 64,224
# ============================================================
